# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_node(5)
G.add_node(6)

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
G.add_edges_from([(1,2),(2,3),(3,4),(4,5)])

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (2, 3), (3, 4), (4, 5)])

# %%
# if an edge not in the vertex set is added 
# it gets created automatically
G.add_edge(1,6)
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
# visualizing graph
nx.draw(G, with_labels=1)

# %%
Z = nx.Graph()
Z.add_nodes_from(range(1,6))
Z.add_edges_from([(1,2),(2,3),(4,5)])
nx.draw(Z, with_labels=1, node_color='g')

# %%
K25 = nx.complete_graph(25)
nx.draw(K25, with_labels=1, node_color='r')

# %%
# playing with layouts
pos = nx.circular_layout(K25)
nx.draw(K5,pos) # can directly use nx.draw_circular(K5)

# %%
nx.draw_spring(K25)

# %%
nx.draw_spectral(K25)

# %%
K25.order() # no of vertices
# Out:
# 25

# %%
K25.size() # no of edges
# Out:
# 300

# %%
# finding a degree sequence is graphic or not
l = [2,2,2]
nx.is_graphical(l)
# Out:
# True

# %%
#  path graph
P = nx.path_graph(5)
nx.draw(P, with_labels=1)

# %%
# finding articulation point
list(nx.articulation_points(P))
# Out:
# [3, 2, 1]

# %%
# creating a disjoint graph
K5_P = nx.disjoint_union(K5, P)
nx.draw(K25_P)

# %%
# checking connectivity
nx.is_connected(K5_P)
# Out:
# False

# %%
S= nx.star_graph(11)
nx.draw(S)
